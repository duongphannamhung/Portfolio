# %% [markdown]
# <a href="https://colab.research.google.com/github/duongphannamhung/Portfolio/blob/main/pull_data_from_clickhouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from clickhouse_driver import Client
import pandas as pd

# %%
client = Client('live.primedata.ai',
                port= 9000,  
                user='datacracy',
                password='G2Cfaz8psF',
                connect_timeout=60)

# %%
result41 = client.execute("SELECT * FROM eventify_stag.events WHERE event_name IN ('identify','mergedProfile','erp_order_completed','erp_item_order_completed') AND ('2021-04-01 00:00:00'<=at) AND (at<='2021-04-15 00:00:00')")

# %%
_41=pd.DataFrame(result41)
_41.to_csv(r'D:\OneDrive\DATACracy\Scalar\_41.csv')
_41.sort_values(16)
# Out:
#                                 0   1                            2   \
# 74922  1udaXQB3O4WNHTyYpy2ja8I9DEI   1  1udaXSOvIhp20KfYcOYq6WSJ7Wq
# 74490  1wPIucAbK0US61q5iZUgIKNTaoF   1  1udaX0D7fQd0E4M01WZ4eaUdhVL
# 74495  1wPIujbvDLtYZjUwcpSD8VMu80P   1  1udaX0D7fQd0E4M01WZ4eaUdhVL
# 74504  1udaWyvsPMwVmeCKdcKX3DywdcS   1  1udaX0eC6IFwwbsMr8Ui6V1VkuD
# 74505  1wPJ6B0GUhOYcc9Y0tRf4dCx4Dh   1  1udaX0eC6IFwwbsMr8Ui6V1VkuD
# ...                            ...  ..                          ...
# 53744  1uddMo38wAdlNYn9iNjBmNf9Fld   1  1uddMqRzwN1YmmGEbbZr67tjoQZ
# 53745  1wPiSDsjGaPKkG101AvroFNhhpW   1  1uddMqRzwN1YmmGEbbZr67tjoQZ
# 53746  1wPiSAvIZGq1sa4fii43d6EwXlX   1  1uddMqRzwN1YmmGEbbZr67tjoQZ
# 53739  1wPhyS9WYelxqU66HCiV93D8hEg   1  1uddMojlF7qY343idxGReUHZRIa
# 52471  1wPjyxholxf2KEzon1KkXi1FvPp   1  1ucgMCFrvG7OabqlgD99KScFfwD
#
#                   3                                     4   \
# 74922       identify  acfe43b4-61f3-4230-bbb3-6e7c61898ade
# ...
